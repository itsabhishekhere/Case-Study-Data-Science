# %% [markdown]
# # **Case Study: Cholera (Analysis, Comparison & Visualization)**

# %% [markdown]
# # Cholera
#
# <hr>
#
# **Cholera** is a disease caused by bacteria that produce a watery **diarrhea** that can rapidly lead to **dehydration**.
#
# Cholera is an **acute diarrhoeal disease** that can kill within hours if left untreated.
#
# A global strategy on cholera control with a target to reduce cholera deaths by 90% was launched in 2017.
#
# Safe oral cholera vaccines should be used in conjunction with improvements in water and sanitation to control cholera outbreaks and for prevention in areas known to be high risk for cholera.
#
# <div style="">
#     <div style="width:70%"><img src="https://images.medicinenet.com/images/article/main_image/cholera2.jpg"/></div>
#
# <hr>
#
# ## Overview:
# Cholera is an acute diarrhoeal infection caused by eating or drinking food or water that is contaminated with the bacterium Vibrio cholerae. Cholera remains a global threat to public health and is an indicator of inequity and lack of social development. Researchers have estimated that every year, there are 1.3 to 4.0 million cases of cholera, and 21 000 to 143 000 deaths worldwide due to the infection.
#
# Cholera, caused by the bacteria Vibrio cholerae, is rare in the United States and other industrialized nations. However, globally, cholera cases have increased steadily since 2005 and the disease still occurs in many places including Africa, Southeast Asia, and Haiti. CDC responds to cholera outbreaks across the world using its Global Water, Sanitation and Hygiene (WASH) expertise.
#
# Cholera can be life-threatening but it is easily prevented and treated. Travelers, public health and medical professionals and outbreak responders should be aware of areas with high rates of cholera, know how the disease spreads, and what to do to prevent it.
#
# **Read More About it from Reference Links**
#
# ## Illness and Symptoms (as per **CDC**):
# Approximately one in ten (5-10%) of infected persons will have severe cholera which in the early stages includes:
# * profuse watery diarrhea, sometimes described as “rice-water stools,”
# * vomiting
# * rapid heart rate
# * loss of skin elasticity
# * dry mucous membranes
# * low blood pressure
# * thirst
# * muscle cramps
# * restlessness or irritability
#
# ## Prevention:
#
# * Most important prevention from **Cholera** is **Clean Water** and **Proper Sanitation**.
#
# * **Vacciantion** of Oral Cholera is other most effected prevention, according to **WHO**.
#
# * Basic Hygienic Behaviours like **Washing Hand** with **Soap** frequently and mostly before and after food.
#
# * Increasing your Immune Stanima also best for fighting Cholera (**YOGA** and **Meditation** are great way to have it)
#
# ## Vaccines:
# According to **WHO**, in year 2013 **OCV(Oral cholera vaccines)** creation took place and since than more than **50 Million** doses of these were given under different campaings.
#
#  <hr>
#
# ### Dataset:
# **https://www.kaggle.com/imdevskp/cholera-dataset**<br>
# Cholera Dataset by DevKumar KP
#
# <hr>
#
# ### Reference Sources:
# * [WHO](https://www.who.int/news-room/fact-sheets/detail/cholera)
# * [WHO](https://www.who.int/health-topics/cholera#tab=tab_1)
# * [CDC](https://www.cdc.gov/cholera/index.html)

# %% [markdown]
# ## <font style="color:#9e7fec">Author:</font>
# <font style="color:red;font-size:20px"><b>ABHISHEK</b></font>
#
# ### Contact with me:
# * <font style="color:#7fecde; font-size:20px;line-height:24px;">Follow me on <a href='https://www.linkedin.com/in/abhishek-5b642580/'>LinkedIn</a>.</font>
# * <font style="color:#7fecde; font-size:20px;line-height:24px;">Follow me on <a href='https://www.kaggle.com/iabhishekmaurya'>Kaggle</a>.</font>
# * <font style="color:#7fecde; font-size:20px;line-height:24px;">My other Work:<ul>
#   <li><a href='https://www.kaggle.com/iabhishekmaurya/used-car-price-prediction'>Used Car Price Pridiction </a><a href='https://used-car-price-pred.herokuapp.com/'>  (Deployed Link)</a></li>
#   <li><a href='https://www.kaggle.com/iabhishekmaurya/exploration-placement-data'>Exploration Series</a></li>
#   <li><a href='https://www.kaggle.com/iabhishekmaurya/notebooks'>More NoteBooks</a></li>
# </ul> </font>
# <hr>
#
# <font style="color:orange;font-size:18px"><b>A Humble Request: IF you liked my work </b></font>
# <font style="color:red;font-size:18px"><b>DO GIVE UPVOTE</b></font>
#
# <font style="color:green;font-size:18px">And Guess What, It won't cost any, instead Motivates ME</font>

# %% [markdown]
# # Content :
# <hr>
#
# * [Cholera](#Cholera)
# * [Libraries/Modules Imports](#Libraries/Modules-Imports)
# * [Dataset and Some Basic Information of it](#Dataset-and-Some-Basic-Information-of-it)
# * [Some Preprocessing](#Some-Preprocessing)
# * [Basic Analysis](#Basic-Analysis)
#     * [Countries Record](#Countries-Record)
#     * [WHO Regions Report](#WHO-Regions-Report)
# * [Analysis With Visualization](#Analysis-With-Visualization)
#     * [Top 10 Countries](#Top-10-Countries)
#     * [Correlation](#Correlation)
# * [Time Graph](#Time-Graph)
#     * [Top 10 Countries](#Graphs-for-Top-10-Countries-w.r.t.-Cases)
#     * [WHO Regions](#Graphs-for-WHO-Regions-w.r.t.-Cases)
# * [Scatter plot: a stroll through time](#Scatter-plot-a-stroll-through-time)
# * **[INDIA (MORE UPCOMING)](#INDIA)**

# %% [markdown]
# # Libraries/Modules Imports
# <hr>
#
# * **Numpy** - fundamental package for scientific computing (I would say Backbone)
#
# * **Pandas** - open source data analysis and manipulation tool
#
# * **Matplotlib** - Comprehensive library for interactive visualizations
#
# * **Seaborn** -  Python data visualization library based on matplotlib
#
# * **Plotly** - for interative plots

# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
sns.set()

# %% [markdown]
# # Dataset and Some Basic Information of it
# <hr>
#
# Here I worked on dataset of Cholera [Link](https://www.kaggle.com/imdevskp/cholera-dataset)

# %%
# Reading the dataset
chl_data = pd.read_csv('../input/cholera-dataset/data.csv')
chl_data.head()
# Out:
#        Country  Year Number of reported cases of cholera  \
# 0  Afghanistan  2016                                 677
# 1  Afghanistan  2015                               58064
# 2  Afghanistan  2014                               45481
# 3  Afghanistan  2013                                3957
# 4  Afghanistan  2012                                  12
#
#   Number of reported deaths from cholera Cholera case fatality rate  \
# 0                                      5                        0.7
# 1                                      8                       0.01
# 2                                      4                        0.0
# 3                                     14                       0.35
# 4                                      0                        0.1
#
#               WHO Region
# 0  Eastern Mediterranean
# 1  Eastern Mediterranean
# 2  Eastern Mediterranean
# 3  Eastern Mediterranean
# 4  Eastern Mediterranean

# %%
print("Shape of data: ",chl_data.shape)
# Out:
# Shape of data:  (2492, 6)

# %%
chl_data['Country'].value_counts()
# Out:
# India                         64
# Malaysia                      49
# Viet Nam                      47
# Iran (Islamic Republic of)    45
# Myanmar                       45
#                               ..
# Hungary                        1
# Samoa                          1
# Estonia                        1
# Maldives                       1
# Tonga                          1
# Name: Country, Length: 162, dtype: int64

# %%
chl_data['WHO Region'].value_counts()
# Out:
# Africa                   991
# Western Pacific          391
# Europe                   327
# South-East Asia          292
# Americas                 256
# Eastern Mediterranean    235
# Name: WHO Region, dtype: int64

# %%
chl_data.columns
# Out:
# Index(['Country', 'Year', 'Number of reported cases of cholera',
#        'Number of reported deaths from cholera', 'Cholera case fatality rate',
#        'WHO Region'],
#       dtype='object')

# %% [markdown]
# # Some Preprocessing
# <hr>
#
# Is Time for some **Data Preprocessing**

# %%
# A Simple Column Names
chl_data = chl_data.rename(columns={"Number of reported cases of cholera":"Cases",
                                   "Number of reported deaths from cholera":"Deaths",
                                   "Cholera case fatality rate":"Fatality Rate"})

# %%
# Count of Null Data
chl_data.isnull().sum()
# Out:
# Country            0
# Year               0
# Cases             22
# Deaths           117
# Fatality Rate    127
# WHO Region         0
# dtype: int64

# %%
# Filling NULL with '0'
chl_data['Cases'] = chl_data['Cases'].fillna('0')
chl_data['Deaths'] = chl_data['Deaths'].fillna('0')
chl_data['Fatality Rate'] = chl_data['Fatality Rate'].fillna('0')

# Replacing 'Unknown' Values with '0'
chl_data['Cases'] = chl_data['Cases'].replace('Unknown', '0')
chl_data['Deaths'] = chl_data['Deaths'].replace('Unknown', '0')
chl_data['Fatality Rate'] = chl_data['Fatality Rate'].replace('Unknown', '0')

# Removing WhiteSpaces 
chl_data['Cases'] = chl_data['Cases'].str.replace(" ","")
chl_data['Deaths'] = chl_data['Deaths'].str.replace(" ","")
chl_data['Fatality Rate'] = chl_data['Fatality Rate'].str.replace(" ","")

# %%
# Info about Dataframe
chl_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2492 entries, 0 to 2491
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country        2492 non-null   object
#  1   Year           2492 non-null   int64
#  2   Cases          2492 non-null   object
#  3   Deaths         2492 non-null   object
#  4   Fatality Rate  2492 non-null   object
#  5   WHO Region     2492 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 116.9+ KB

# %%
# Converting 'Cases' & 'Deaths' Dtype from Object to int
chl_data['Cases'] = chl_data['Cases'].astype(int)
chl_data['Deaths'] = chl_data['Deaths'].astype(int)

# %%
# Creating Dataframe w.r.t. Countries
a = ['Country']
b = ['Cases','Deaths']
country_wise = chl_data.groupby(a)[b].sum()

# Creating Dataframe w.r.t. Regions
a = ['WHO Region']
b = ['Cases','Deaths']
region_wise = chl_data.groupby(a)[b].sum()

# %%
# Creating New columns(Fatality Rate, Recovery, and Recvery Rate) for **Country DataFrame**
country_wise["Fatality Rate"] = np.round(100*country_wise["Deaths"]/country_wise["Cases"],2)
country_wise["Recovery"] = country_wise["Cases"] - country_wise["Deaths"]
country_wise["Recovery Rate"] = np.round(100*(country_wise["Cases"] - country_wise["Deaths"])/country_wise["Cases"],2)
country_wise = country_wise[[ 'Cases', 'Recovery', 'Deaths', 'Recovery Rate', 'Fatality Rate']]

# Creating New columns(Fatality Rate, Recovery, and Recvery Rate) for **Region DataFrame**
region_wise["Fatality Rate"] = np.round(100*region_wise["Deaths"]/region_wise["Cases"],2)
region_wise["Recovery"] = region_wise["Cases"] - region_wise["Deaths"]
region_wise["Recovery Rate"] = np.round(100*(region_wise["Cases"] - region_wise["Deaths"])/region_wise["Cases"],2)
region_wise = region_wise[[ 'Cases', 'Recovery', 'Deaths', 'Recovery Rate', 'Fatality Rate']]

# Sorting both DataFrames w.r.t **Cases**
country_wise = country_wise.sort_values(by=['Cases'], ascending=False)
region_wise = region_wise.sort_values(by=['Cases'], ascending=False)

# %% [markdown]
# # Basic Analysis
# <hr>
# Record of Data w.r.t. Countries and WHO Regions

# %% [markdown]
# ## Countries Record

# %%
country_wise.style.background_gradient(cmap='Blues',subset=["Cases"])\
                        .background_gradient(cmap='Greens',subset=["Recovery"])\
                        .background_gradient(cmap='Reds',subset=["Deaths"])\
                        .background_gradient(cmap='CMRmap',subset=["Recovery Rate"])\
                        .background_gradient(cmap='Greys',subset=["Fatality Rate"])\
                        .format("{:.0f}",subset=["Cases", "Recovery", "Deaths", "Recovery Rate", "Fatality Rate"])
# Out:
# <style  type="text/css" >
#     #T_cea1be8e_cd24_11ea_8d20_0242ac130202row0_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row0_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row0_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row0_col3 {
#             background-color:  #3c26a4;
#             color:  #f1f1f1;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row0_col4 {
#             background-color:  #3f3f3f;
#             color:  #f1f1f1;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row1_col0 {
#             background-color:  #4f9bcb;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row1_col1 {
#             background-color:  #005e26;
#             color:  #f1f1f1;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row1_col2 {
#             background-color:  #fff2ec;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row1_col3 {
#             background-color:  #fafae7;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row1_col4 {
#             background-color:  #fcfcfc;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row2_col0 {
#             background-color:  #5da5d1;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row2_col1 {
#             background-color:  #05712f;
#             color:  #f1f1f1;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row2_col2 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row2_col3 {
#             background-color:  #fdfdf3;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row2_col4 {
#             background-color:  #fefefe;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row3_col0 {
#             background-color:  #9cc9e1;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row3_col1 {
#             background-color:  #52b365;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row3_col2 {
#             background-color:  #ffeee6;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row3_col3 {
#             background-color:  #ededa3;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row3_col4 {
#             background-color:  #f4f4f4;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row4_col0 {
#             background-color:  #b9d6ea;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row4_col1 {
#             background-color:  #8ed08b;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row4_col2 {
#             background-color:  #ffebe2;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row4_col3 {
#             background-color:  #e6d95f;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row4_col4 {
#             background-color:  #e9e9e9;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row5_col0 {
#             background-color:  #c8dcf0;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row5_col1 {
#             background-color:  #a0d99b;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row5_col2 {
#             background-color:  #fff3ed;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row5_col3 {
#             background-color:  #f5f5cf;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row5_col4 {
#             background-color:  #f9f9f9;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row6_col0 {
#             background-color:  #cadef0;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row6_col1 {
#             background-color:  #a8dca2;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row6_col2 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row6_col3 {
#             background-color:  #f0f0b3;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row6_col4 {
#             background-color:  #f6f6f6;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row7_col0 {
#             background-color:  #cadef0;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row7_col1 {
#             background-color:  #acdea6;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row7_col2 {
#             background-color:  #ffeee7;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row7_col3 {
#             background-color:  #e6df6f;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row7_col4 {
#             background-color:  #ececec;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row8_col0 {
#             background-color:  #cddff1;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row8_col1 {
#             background-color:  #d7efd1;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row8_col2 {
#             background-color:  #fcb499;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row8_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row8_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row9_col0 {
#             background-color:  #d1e2f3;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row9_col1 {
#             background-color:  #b6e2af;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row9_col2 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row9_col3 {
#             background-color:  #fbfbeb;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row9_col4 {
#             background-color:  #fdfdfd;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row10_col0 {
#             background-color:  #d6e6f4;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row10_col1 {
#             background-color:  #c7e9c0;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row10_col2 {
#             background-color:  #fff1ea;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row10_col3 {
#             background-color:  #e7e787;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row10_col4 {
#             background-color:  #f1f1f1;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row11_col0 {
#             background-color:  #dce9f6;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row11_col1 {
#             background-color:  #d0edca;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row11_col2 {
#             background-color:  #fff2ec;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row11_col3 {
#             background-color:  #e9e98f;
#             color:  #000000;
#         }    #T_cea1be8e_cd24_11ea_8d20_0242ac130202row11_col4 {
#             background-color:  #f2f2f2;
#             color:  #0

# %% [markdown]
# ## WHO Regions Report

# %%
region_wise.style.background_gradient(cmap='Blues',subset=["Cases"])\
                        .background_gradient(cmap='Greens',subset=["Recovery"])\
                        .background_gradient(cmap='Reds',subset=["Deaths"])\
                        .background_gradient(cmap='CMRmap',subset=["Recovery Rate"])\
                        .background_gradient(cmap='Greys',subset=["Fatality Rate"])\
                        .format("{:.0f}",subset=["Cases", "Recovery", "Deaths", "Recovery Rate", "Fatality Rate"])
# Out:
# <style  type="text/css" >
#     #T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row0_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row0_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row0_col2 {
#             background-color:  #fdc6b0;
#             color:  #000000;
#         }    #T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row0_col3 {
#             background-color:  #eaea97;
#             color:  #000000;
#         }    #T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row0_col4 {
#             background-color:  #f3f3f3;
#             color:  #000000;
#         }    #T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row1_col0 {
#             background-color:  #4191c6;
#             color:  #000000;
#         }    #T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row1_col1 {
#             background-color:  #86cc85;
#             color:  #000000;
#         }    #T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row1_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row1_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row1_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row2_col0 {
#             background-color:  #4a98c9;
#             color:  #000000;
#         }    #T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row2_col1 {
#             background-color:  #43ac5e;
#             color:  #000000;
#         }    #T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row2_col2 {
#             background-color:  #fff0e8;
#             color:  #000000;
#         }    #T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row2_col3 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row2_col4 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row3_col0 {
#             background-color:  #c8dcf0;
#             color:  #000000;
#         }    #T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row3_col1 {
#             background-color:  #c9eac2;
#             color:  #000000;
#         }    #T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row3_col2 {
#             background-color:  #fff0e9;
#             color:  #000000;
#         }    #T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row3_col3 {
#             background-color:  #f7f7d7;
#             color:  #000000;
#         }    #T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row3_col4 {
#             background-color:  #fafafa;
#             color:  #000000;
#         }    #T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row4_col0 {
#             background-color:  #e4eff9;
#             color:  #000000;
#         }    #T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row4_col1 {
#             background-color:  #e9f7e5;
#             color:  #000000;
#         }    #T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row4_col2 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row4_col3 {
#             background-color:  #ebeb9b;
#             color:  #000000;
#         }    #T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row4_col4 {
#             background-color:  #f3f3f3;
#             color:  #000000;
#         }    #T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row5_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row5_col1 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row5_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row5_col3 {
#             background-color:  #f6f6d3;
#             color:  #000000;
#         }    #T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row5_col4 {
#             background-color:  #fafafa;
#             color:  #000000;
#         }</style><table id="T_ceb2ba0e_cd24_11ea_8d20_0242ac130202" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Cases</th>        <th class="col_heading level0 col1" >Recovery</th>        <th class="col_heading level0 col2" >Deaths</th>        <th class="col_heading level0 col3" >Recovery Rate</th>        <th class="col_heading level0 col4" >Fatality Rate</th>    </tr>    <tr>        <th class="index_name level0" >WHO Region</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ceb2ba0e_cd24_11ea_8d20_0242ac130202level0_row0" class="row_heading level0 row0" >Africa</th>
#                         <td id="T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row0_col0" class="data row0 col0" >3567823</td>
#                         <td id="T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row0_col1" class="data row0 col1" >3420483</td>
#                         <td id="T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row0_col2" class="data row0 col2" >147340</td>
#                         <td id="T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row0_col3" class="data row0 col3" >96</td>
#                         <td id="T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row0_col4" class="data row0 col4" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_ceb2ba0e_cd24_11ea_8d20_0242ac130202level0_row1" class="row_heading level0 row1" >South-East Asia</th>
#                         <td id="T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row1_col0" class="data row1 col0" >2238439</td>
#                         <td id="T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row1_col1" class="data row1 col1" >1544832</td>
#                         <td id="T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row1_col2" class="data row1 col2" >693607</td>
#                         <td id="T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row1_col3" class="data row1 col3" >69</td>
#                         <td id="T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row1_col4" class="data row1 col4" >31</td>
#             </tr>
#             <tr>
#                         <th id="T_ceb2ba0e_cd24_11ea_8d20_0242ac130202level0_row2" class="row_heading level0 row2" >Americas</th>
#                         <td id="T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row2_col0" class="data row2 col0" >2149448</td>
#                         <td id="T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row2_col1" class="data row2 col1" >2126643</td>
#                         <td id="T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row2_col2" class="data row2 col2" >22805</td>
#                         <td id="T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row2_col3" class="data row2 col3" >99</td>
#                         <td id="T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row2_col4" class="data row2 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_ceb2ba0e_cd24_11ea_8d20_0242ac130202level0_row3" class="row_heading level0 row3" >Eastern Mediterranean</th>
#                         <td id="T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row3_col0" class="data row3 col0" >866758</td>
#                         <td id="T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row3_col1" class="data row3 col1" >847449</td>
#                         <td id="T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row3_col2" class="data row3 col2" >19309</td>
#                         <td id="T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row3_col3" class="data row3 col3" >98</td>
#                         <td id="T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row3_col4" class="data row3 col4" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_ceb2ba0e_cd24_11ea_8d20_0242ac130202level0_row4" class="row_heading level0 row4" >Western Pacific</th>
#                         <td id="T_ceb2ba0e_cd24_11ea_8d20_0242ac130202row4_col0" class="data row4 col0" >346456</td>
#                         <td id="T_ceb2ba0e_cd24_11ea_8d20

# %% [markdown]
# # Analysis With Visualization
# <hr>
# Now, we will dive more in the data

# %% [markdown]
# ## Top 10 Countries
# <hr>
# It's better to find out **Top 10** Countries in terms of Numbers.

# %%
# Reseting Index for Countries DataFrames
country_wise = country_wise.reset_index()

# Plot for Number of Cases
fig, ax = plt.subplots()
fig.set_size_inches(10, 5)
plt.xticks(rotation=90);
sns.barplot(y = country_wise.sort_values('Cases')["Country"].values[-10:],
            x = country_wise.sort_values('Cases')["Cases"].values[-10:],
           color="#8ABAD3FF")
ax.set_xlabel('Cases', fontsize=15)
ax.set_ylabel('Country', fontsize=15)
ax.set_title('Top 10 Countries (Discovered Cases)', fontsize=15)

# Plot for Number of Recoveries
fig, ax = plt.subplots()
fig.set_size_inches(10, 5)
plt.xticks(rotation=90);
sns.barplot(y = country_wise.sort_values('Recovery')["Country"].values[-10:],
            x = country_wise.sort_values('Recovery')["Recovery"].values[-10:],
           color="#339E66FF")
ax.set_xlabel('Recovery Cases', fontsize=15)
ax.set_ylabel('Country', fontsize=15)
ax.set_title('Top 10 Countries (Recovery)', fontsize=15)

# Plot for Number of Deaths
fig, ax = plt.subplots()
fig.set_size_inches(10, 5)
plt.xticks(rotation=90);
sns.barplot(y = country_wise.sort_values('Deaths')["Country"].values[-10:],
            x = country_wise.sort_values('Deaths')["Deaths"].values[-10:],
           color="#EE2737FF")
ax.set_xlabel('Deaths Cases', fontsize=15)
ax.set_ylabel('Country', fontsize=15)
ax.set_title('Top 10 Countries (Deaths)', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Top 10 Countries (Deaths)')

# %% [markdown]
# ## Correlation
# <hr>
# I used **Heat Map** for it.

# %%
plt.figure(figsize=(9,9))
sns.heatmap(country_wise.corr(),annot=True,cmap='RdYlGn')
plt.tick_params(size=5,labelsize = 13,rotation=90)
plt.show()

# %% [markdown]
# # Time Graph
# <hr>
# **Time Graphs** are best to understand the growth or decline in a long period.
#
# Here, I used **'Year'** column for that.

# %% [markdown]
# ## Graphs for Top 10 Countries w.r.t. Cases
# <hr>

# %%
# Listing the Countries Names
country_list = country_wise.sort_values('Cases')["Country"].values[-10:]

# Ploting with Some Preprocessing
for country_name in country_list:
    df = chl_data[chl_data['Country'] == country_name]
    df = df.sort_values('Year')
    x = df['Cases']
    y = df['Deaths']
    x.reset_index(drop=True)
    case = 0
    death = 0
    cases = []
    deaths = []
    for i in range(len(x)):
        case = case + x.iloc[i]
        death = death + y.iloc[i]
        cases.append(case)
        deaths.append(death)
    df['Total Cases'] = cases
    df['Total Deaths'] = deaths
    max_total_cases_yr = df['Year'].max()
    max_total_cases = float(df[df['Year'] == max_total_cases_yr]['Total Cases'])
    max_total_deaths = float(df[df['Year'] == max_total_cases_yr]['Total Deaths'])
    if df['Cases'].sum() >= 0 and df.shape[0] > 5:
        fig, ax = plt.subplots()
        df.plot(x='Year', y='Total Cases', ax=ax)
        df.plot(x='Year', y='Total Deaths', ax=ax)
        plt.scatter(x= [max_total_cases_yr], y=[max_total_cases], s=70, clip_on=False, linewidth=0)
        plt.annotate(int(max_total_cases), xy=[max_total_cases_yr, max_total_cases], xytext=[7, -2], textcoords='offset points')
        plt.scatter(x= [max_total_cases_yr], y=[max_total_deaths], s=70, clip_on=False, linewidth=0)
        plt.annotate(int(max_total_deaths), xy=[max_total_cases_yr, max_total_deaths], xytext=[7, -2], textcoords='offset points')
        ax.set_title(country_name)

# %% [markdown]
# ## Graphs for WHO Regions w.r.t. Cases
# <hr>

# %%
# Listing WHO Regions Names
region_wise = region_wise.reset_index()
region_list = region_wise.sort_values('Deaths')["WHO Region"]

df_region = chl_data.groupby(['WHO Region', 'Year']).sum()
df_region = df_region.reset_index()

for region_name in region_list:
    df = df_region[df_region['WHO Region'] == region_name]
    df = df.sort_values('Year')
    x = df['Cases']
    y = df['Deaths']
    x.reset_index(drop=True)
    case = 0
    death = 0
    cases = []
    deaths = []
    for i in range(len(x)):
        case = case + x.iloc[i]
        death = death + y.iloc[i]
        cases.append(case)
        deaths.append(death)
    df['Total Cases'] = cases
    df['Total Deaths'] = deaths
    max_total_cases_yr = df['Year'].max()
    max_total_cases = float(df[df['Year'] == max_total_cases_yr]['Total Cases'])
    max_total_deaths = float(df[df['Year'] == max_total_cases_yr]['Total Deaths'])
    if df['Cases'].sum() >= 0:
        fig, ax = plt.subplots()
        df.plot(x='Year', y='Total Cases', ax=ax)
        df.plot(x='Year', y='Total Deaths', ax=ax)
        plt.scatter(x= [max_total_cases_yr], y=[max_total_cases], s=70, clip_on=False, linewidth=0)
        plt.annotate(int(max_total_cases), xy=[max_total_cases_yr, max_total_cases], xytext=[7, -2], textcoords='offset points')
        plt.scatter(x= [max_total_cases_yr], y=[max_total_deaths], s=70, clip_on=False, linewidth=0)
        plt.annotate(int(max_total_deaths), xy=[max_total_cases_yr, max_total_deaths], xytext=[7, -2], textcoords='offset points')
        ax.set_title(region_name)

# %% [markdown]
# ## Scatter plot a stroll through time

# %%
fig = px.scatter(
    data_frame=chl_data, 
    x="Deaths", 
    y="Cases", 
    animation_frame="Year", 
    animation_group="Country", 
    color="Country",
    size = "Cases",
    hover_name="Country", 
    facet_col="WHO Region",
    size_max=45,
    category_orders={'Year':list(range(1980,2010))}     
)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="ccdc4dbe-3551-44b2-bb97-6741fb86f1c8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ccdc4dbe-3551-44b2-bb97-6741fb86f1c8")) {
#                     Plotly.newPlot(
#                         'ccdc4dbe-3551-44b2-bb97-6741fb86f1c8',
#                         [{"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Algeria<br>Year=1980<br>WHO Region=Africa<br>Deaths=%{x}<br>Cases=%{marker.size}<extra></extra>", "hovertext": ["Algeria"], "ids": ["Algeria"], "legendgroup": "Algeria", "marker": {"color": "#00cc96", "size": [614], "sizemode": "area", "sizeref": 168.05481481481482, "symbol": "circle"}, "mode": "markers", "name": "Algeria", "orientation": "v", "showlegend": true, "type": "scatter", "x": [18], "xaxis": "x3", "y": [614], "yaxis": "y3"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Australia<br>Year=1980<br>WHO Region=Western Pacific<br>Deaths=%{x}<br>Cases=%{marker.size}<extra></extra>", "hovertext": ["Australia"], "ids": ["Australia"], "legendgroup": "Australia", "marker": {"color": "#FF6692", "size": [2], "sizemode": "area", "sizeref": 168.05481481481482, "symbol": "circle"}, "mode": "markers", "name": "Australia", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0], "xaxis": "x5", "y": [2], "yaxis": "y5"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Belgium<br>Year=1980<br>WHO Region=Europe<br>Deaths=%{x}<br>Cases=%{marker.size}<extra></extra>", "hovertext": ["Belgium"], "ids": ["Belgium"], "legendgroup": "Belgium", "marker": {"color": "#ab63fa", "size": [1], "sizemode": "area", "sizeref": 168.05481481481482, "symbol": "circle"}, "mode": "markers", "name": "Belgium", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0], "xaxis": "x2", "y": [1], "yaxis": "y2"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Benin<br>Year=1980<br>WHO Region=Africa<br>Deaths=%{x}<br>Cases=%{marker.size}<extra></extra>", "hovertext": ["Benin"], "ids": ["Benin"], "legendgroup": "Benin", "marker": {"color": "#19d3f3", "size": [3], "sizemode": "area", "sizeref": 168.05481481481482, "symbol": "circle"}, "mode": "markers", "name": "Benin", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0], "xaxis": "x3", "y": [3], "yaxis": "y3"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Burundi<br>Year=1980<br>WHO Region=Africa<br>Deaths=%{x}<br>Cases=%{marker.size}<extra></extra>", "hovertext": ["Burundi"], "ids": ["Burundi"], "legendgroup": "Burundi", "marker": {"color": "#00cc96", "size": [2039], "sizemode": "area", "sizeref": 168.05481481481482, "symbol": "circle"}, "mode": "markers", "name": "Burundi", "orientation": "v", "showlegend": true, "type": "scatter", "x": [28], "xaxis": "x3", "y": [2039], "yaxis": "y3"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Cameroon<br>Year=1980<br>WHO Region=Africa<br>Deaths=%{x}<br>Cases=%{marker.size}<extra></extra>", "hovertext": ["Cameroon"], "ids": ["Cameroon"], "legendgroup": "Cameroon", "marker": {"color": "#19d3f3", "size": [229], "sizemode": "area", "sizeref": 168.05481481481482, "symbol": "circle"}, "mode": "markers", "name": "Cameroon", "orientation": "v", "showlegend": true, "type": "scatter", "x": [23], "xaxis": "x3", "y": [229], "yaxis": "y3"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Country=China<br>Year=1980<br>WHO Region=Western Pacific<br>Deaths=%{x}<br>Cases=%{marker.size}<extra></extra>", "hovertext": ["China"], "ids": ["China"], "legendgroup": "China", "marker": {"color": "#636efa", "size": [88], "sizemode": "area", "sizeref": 168.05481481481482, "symbol": "circle"}, "mode": "markers", "name": "China", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0], "xaxis": "x5", "y": [88], "yaxis": "y5"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Democratic People's Republic of Korea<br>Year=1980<br>WHO Region=Western Pacific<br>Deaths=%{x}<br>Cases=%{marker.size}<extra></extra>", "hovertext": ["Democratic People's Republic of Korea"], "ids": ["Democratic People's Republic of Korea"], "legendgroup": "Democratic People's Republic of Korea", "marker": {"color": "#FF97FF", "size": [170], "sizemode": "area", "sizeref": 168.05481481481482, "symbol": "circle"}, "mode": "markers", "name": "Democratic People's Republic ...

# %% [markdown]
# # INDIA
# ## (more Upcoming)

# %%
fig, ax = plt.subplots()
chl_data[chl_data['Country'] == 'India'].plot(x='Year', y='Cases', ax=ax, legend=False)
chl_data[chl_data['Country'] == 'India'].plot(x='Year', y='Deaths', ax=ax, legend=False)
ax.set_title("India")
# Out:
# Text(0.5, 1.0, 'India')

# %% [markdown]
# ## <font style="color:#9e7fec">Upcoming More... Stay Connect:</font>
#
# <font style="color:orange;font-size:18px"><b>A Humble Request: IF you liked my work </b></font>
# <font style="color:red;font-size:18px"><b>DO GIVE UPVOTE</b></font>
#
# <font style="color:green;font-size:18px">And Guess What, It won't cost any, instead Motivates ME</font>
#
# ### Till then:
#  <font style="color:#7fecde; font-size:20px;line-height:24px;">My other Work:<ul>
#   <li><a href='https://www.kaggle.com/iabhishekmaurya/used-car-price-prediction'>Used Car Price Pridiction </a><a href='https://used-car-price-pred.herokuapp.com/'>  (Deployed Link)</a></li>
#   <li><a href='https://www.kaggle.com/iabhishekmaurya/exploration-placement-data'>Exploration Series</a></li>
#   <li><a href='https://www.kaggle.com/iabhishekmaurya/notebooks'>More NoteBooks</a></li>
# </ul> </font>
# <hr>
#
# <font style="color:green;font-size:18px">BE SAFE & HAPPY CODING 👨🏻‍💻</font>
